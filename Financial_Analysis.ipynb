# %%
# important libraries import


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Read the Excel file

data=pd.read_excel("D:/Financial_Analysis/Sample_Superstore(1) (Autosaved).xlsx")
data
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
# Display the first 5 rows

data.head(5)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
data.shape
# Out:
# (1952, 25)

# %%
# Display the count of missing values in each column

print("Missing values before handling:")
data.isnull().sum()
# Out:
# Missing values before handling:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     16
# Country                  0
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
# Fill missing values in 'Product Base Margin' column with its mean
data['Product Base Margin'].fillna(data['Product Base Margin'].mean(),inplace=True)


# Verify missing values after filling
print("\n Missing values after handling 'Postal code'")
print(data.isnull().sum())
# Out:
#  Missing values after handling 'Postal code'
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Country                 0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
# Display the concise summary of the DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   int64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   int64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1952 non-null   float64
#  14  Country               1952 non-null   object
# ...

# %%
# Display descriptive statistics for numeric columns
data.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   1952.000000  1952.000000  1952.000000    1952.000000  1952.000000
# mean   19916.479508     0.048975   109.079221      12.968151  1735.376537
# min       64.000000     0.000000     1.140000       0.490000     3.000000
# 25%    19121.000000     0.020000     6.480000       3.230000   875.000000
# 50%    21164.500000     0.050000    20.990000       6.150000  1738.000000
# 75%    23483.250000     0.080000   100.972500      14.362500  2578.250000
# max    26389.000000     0.210000  6783.020000     164.730000  3403.000000
# std     5957.595627     0.031378   393.481301      17.414631   991.078006
#
#        Product Base Margin   Postal Code                     Order Date  \
# count          1952.000000   1952.000000                           1952
# mean              0.515186  51534.769467  2015-03-29 01:21:08.852459008
# min               0.350000   1001.000000            2015-01-01 00:00:00
# ...

# %%
# Group data by 'Product Category' and calculate the total discount
category_discounts = data.groupby('Product Category')["Discount"].sum()


# Plot the data as a bar plot
category_discounts.plot(kind='bar', color='turquoise', figsize=(8, 6),edgecolor='k')


# Add labels and a title
plt.title('Total Discount by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Discount')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Group by 'Product Category' and calculate the total for 'Unit Price' and 'Sales'
category_summary = data.groupby("Product Category")[["Unit Price", "Sales"]].sum()


# Plot a grouped bar chart
category_summary.plot(kind='bar', figsize=(10, 6), color=['skyblue', 'orange'],edgecolor='k')


# Add labels and title
plt.title('Comparison of Total Unit Price and Sales by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Values')
plt.xticks(rotation=45)  # Rotate x-axis labels
plt.legend(title="Metrics")

plt.show()

# %%
# Group by 'Product Category' and sum up 'Sales'
category_sales = data.groupby("Product Category")["Sales"].sum()


# Print the result
print(category_sales)


# Plotting the total sales by product category
category_sales.plot(kind='bar', color='grey', figsize=(8, 6),edgecolor='k')


# Add title and labels
plt.title('Total Sales by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)  # Rotate x-axis labels for readability

plt.show()
# Out:
# Product Category
# Furniture          660704.31
# Office Supplies    551368.62
# Technology         712264.95
# Name: Sales, dtype: float64

# %%
# Group By 'Region' wise 'Sales'
Region_by_sales= data.groupby("Region")["Sales"].sum()

# Plotting the Total sales Region wise
Region_by_sales.plot(kind='bar', figsize=(9,6), color='green',edgecolor='k')

# Add title and label
plt.title('Total Sales by Region')
plt.xlabel('Region')
plt.ylabel('Total Sales')

plt.show()

# %%
# Grouping by 'Customer Segment' and summarizing
segment_summury=data.groupby('Customer Segment')[['Sales','Profit']].sum()


# Plotting a grouped bar chart
segment_summury.plot(kind='bar', color=['skyblue','grey'], figsize=(9,6), edgecolor='k')

# Adding labels and title
plt.title('Total Sales, Profit by customer segment')
plt.xlabel('Customer segment')
plt.ylabel('Total values')
plt.xticks(rotation=45)# Rotate labels for better readability
plt.legend(title='Matrics')

plt.show()

# %%
# Grouping by 'Customer Segment' and summing 'Discount'
segment_discount=data.groupby('Customer Segment')['Discount'].sum()


# Plotting a donut chart
plt.figure(figsize=(6,8))
colors=['pink','red','blue','yellow']

segment_discount.plot(kind='pie', color=colors, autopct='%1.1f%%', wedgeprops={'width':0.6})

# Adding title
plt.title('Proportion of Discount by Customer Segment')
plt.ylabel('')  # Remove default ylabel for a cleaner look
plt.show()

# %%
# Grouping by 'Product Sub-Category' and calculating the total profit
sub_category_profit=data.groupby('Product Sub-Category')['Profit'].sum()

# Sorting the profits for better visualization
sub_category_profit=sub_category_profit.sort_values(ascending=True)

# Plotting a horizontal bar chart
sub_category_profit.plot(kind='barh', color='orange', figsize=(10,8))


# Adding labels and title
plt.title('Total Profit by Product Sub-Category')
plt.xlabel('Total Profit')
plt.ylabel('Total Sub Category')
plt.grid(axis='x', linestyle='--')
plt.xticks(rotation=45)

plt.show()

# %%
region_wise_profit=data.groupby('Region')['Profit'].sum()
print(region_wise_profit)

# Negative values hata do
region_wise_profit = region_wise_profit[region_wise_profit > 0]

plt.figure(figsize=(10,6))

region_wise_profit.plot(kind='pie',autopct='%1.1f%%', startangle=90, colors=['yellow','purple','lightblue','coral'])

plt.title('Total Profit, Region by Profit')
plt.ylabel('')
plt.show()
# Out:
# Region
# Central    77365.472669
# East       85291.403446
# South     -14424.054379
# West       75844.790102
# Name: Profit, dtype: float64

# %%
# Grouping by 'Product Category' and summing 'Product Base Margin'
category_base_margin=data.groupby("Product Category")["Product Base Margin"].sum()


# Plotting a pie chart
plt.figure(figsize=(8,7))
category_base_margin.plot(kind='pie', autopct='%1.1f%%', colors=['slateblue', 'lightgreen', 'violet'])


# Adding title
plt.title('Proportion of Product Base Margin by Product Category', fontsize=15)
plt.ylabel('')  # Hides the y-axis label
plt.show()

# %%
# Grouping by 'Product Category' and summing 'Shipping Cost'
category_shipping_cost = data.groupby("Product Category")['Shipping Cost'].sum()

# Plotting the data as a bar chart
plt.figure(figsize=(8, 6))
category_shipping_cost.plot(kind='bar', color='coral', edgecolor='k')

# Adding title and labels
plt.title('Total Shipping Cost by Product Category', fontsize=12)
plt.xlabel('Product Category', fontsize=10)
plt.ylabel('Total Shipping Cost', fontsize=10)
plt.xticks(rotation=45)
plt.show()
